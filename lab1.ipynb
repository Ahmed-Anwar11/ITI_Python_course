# %%
x= input("Enter a string:")
y=0
for i in x:
    if i in ["a","e","i","o","u","A","E","I","O","U"]:
        y+= 1
print(y)
# Out:
# Enter a string:uhrfnoiA
# 4

# %%
x="ijtirhi"
for n in range(len(x)):
  if x[n] == ("i"):
    print(n)
# Out:
# 0
# 3
# 6

# %%
 x=int(input("Enter number:"))
for i in range(x):
  i+=1
  for n in range(i):
      n+=1
      print(f"{i}*{n}={n*i}")
# Out:
# Enter number:5
# 1*1=1
# 2*1=2
# 2*2=4
# 3*1=3
# 3*2=6
# 3*3=9
# 4*1=4
# 4*2=8
# 4*3=12
# 4*4=16
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25

# %%
x=4

for i in range(x):
  x-=1
  i+=1
  print(x*" "+i*"*")
# Out:
#    *
#   **
#  ***
# ****

# %%
print(3*"r")
# Out:
# rrr
